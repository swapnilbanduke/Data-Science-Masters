# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
x,y= make_classification(n_samples=10000,n_features=4,n_classes=2,n_clusters_per_class=2)

# %%
df=pd.DataFrame(x)

# %%
sns.scatterplot(df[0],df[1],hue=y)
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.23,random_state=41)

# %%
from sklearn.svm import SVC
svc=SVC(kernel='linear')
svc.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
svc.coef_
# Out:
# array([[ 0.83817193, -0.65874884,  0.03310559, -0.81568264]])

# %%
y_pred=svc.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[1008  131]
#  [ 145 1016]]
# 0.88
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.88      1139
#            1       0.89      0.88      0.88      1161
#
#     accuracy                           0.88      2300
#    macro avg       0.88      0.88      0.88      2300
# weighted avg       0.88      0.88      0.88      2300
